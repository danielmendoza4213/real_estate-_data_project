# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys

import re

from time import sleep
from time import time
from typing import Tuple

# %%
class ImmoScraper:
    def __init__(self):
        self.driver = webdriver.Chrome()
        self.driver.get('https://www.immoweb.be')
        self.handle_privacy_popup()
        self.set_links = set()
        self.failed_HTML = []

    def handle_privacy_popup(self):
        popup = True
        total_sleeping_time = 8
        sleep_per_iter = 0.5
        while popup:
            try:
                btn_verder_surfen = self.driver.find_element_by_xpath('// *[ @ id = "uc-btn-accept-banner"]')
                btn_verder_surfen.click()
                popup = False
            except NoSuchElementException:
                sleep(sleep_per_iter)
                total_sleeping_time -= sleep_per_iter
                if total_sleeping_time < 0:
                    print('Did not find the button.')
                    break

    def choose_transaction_type(self, tran_type: int):
        if transaction_type.lower() == 'buy':
            xpath = '//*[@id="main-content"]/div/div/form/div[1]/div/div/section[1]/div/div/div/div[1]/label'
        else:
            xpath = '//*[@id="main-content"]/div/div/form/div[1]/div/div/section[1]/div/div/div/div[2]/label'
        btn = scraper.driver.find_element_by_xpath(xpath)
        btn.click()
    
    def choose_property_type(self, prop_type: int):
        btn = scraper.driver.find_element_by_xpath('//*[@id="propertyTypes"]/span')
        btn.click()
        if prop_type.lower() == 'house':
            self.click_xpath('//*[@id="propertyTypes-item-0"]')
        elif prop_type.lower() == 'apartment':
            self.click_xpath('//*[@id="propertyTypes-item-1"]')
        elif prop_type.lower() == 'nre_house':
            self.click_xpath('//*[@id="propertyTypes-item-3"]')
        elif prop_type.lower() == 'nre_apartment':
            self.click_xpath('//*[@id="propertyTypes-item-4"]')
    
    def send_price_range(self, price_range):
        mini, maxi = price_range
        min_field = scraper.driver.find_element_by_xpath('//*[@id="minPrice"]')
        min_field.send_keys(mini)
        min_field = scraper.driver.find_element_by_xpath('//*[@id="maxPrice"]')
        min_field.send_keys(maxi)
            
    def click_xpath(self, xpath: str):
        btn = scraper.driver.find_element_by_xpath(xpath)
        btn.click()
    
    def start_scraping(self):
        min_prices = [50000 * i for i in range(8)]
        max_prices = [50000 * i for i in range(1, 8)]
        max_prices.append(1000000000)
        price_range = zip(min_prices, max_prices)
        
        for prop_type in ['nre_house', 'nre_apartment', 'house', 'apartment']:
            for mini, maxi in zip(min_prices, max_prices):
                print(f'Searching for property type "{prop_type}" and price range "{(mini, maxi)}"')
                self.advanced_search(prop_type = prop_type, price_range =  (mini, maxi))
                
    def advanced_search(self, prop_type: str, price_range: Tuple[int]) -> dict:
        self.driver.get('https://www.immoweb.be/en/advanced-search/house/for-sale?countries=BE&page=1&orderBy=relevance')
        self.choose_property_type('apartment')
        self.send_price_range(price_range)
        self.click_xpath('//*[@id="stickySubmitFooter"]/button[2]')
        next_page = True
        
        while next_page:
            lst = self.driver.find_element_by_id("main-content")
            items = lst.find_elements_by_tag_name("li")

            for item in items:
                try:
                    innerHTML = item.get_attribute('innerHTML')
                except:
                    self.failed_HTML.append({"items": items, "item": item})
                if 'href="' in innerHTML:
                    link = innerHTML.split('href="')[1].split('" ')[0]
                    self.set_links.add(link)
            try:
                btn = self.driver.find_element_by_xpath("//span[contains(@class, 'sr-only') and text()='Next page']")
                btn = btn.find_element_by_xpath('..')
                btn.click()
            except NoSuchElementException:
                print('Could not find the  next page button')
                next_page = False
        
    def ask_for_progress(self):
        string = input('continue?')
    
    def save_set(self):
        jsonStr = json.dumps(list(self.set_links))
        loc = f'./data{int(time())}.txt'
        with open(loc, 'w') as outfile:
            json.dump(jsonStr, outfile)

# %%
if __name__ == '__main__':
    scraper = ImmoScraper()
    scraper.start_scraping()
    scraper.save_set()
# Out:
# Could not find the  next page button
# 51
# Could not find the  next page button
# 551
# Could not find the  next page button
# 2182
# Could not find the  next page button
# 6305
# Could not find the  next page button
# 11208
# Could not find the  next page button
# 15532
# Could not find the  next page button
# 18033
# Could not find the  next page button
# 22831
# Could not find the  next page button
# 22861
# Could not find the  next page button
# 23161
# Could not find the  next page button
# 24553
# Could not find the  next page button
# 28601
# Could not find the  next page button
# 32778
# Could not find the  next page button
# 36516
# Could not find the  next page button
# 38803
# Could not find the  next page button
# 43853
# Could not find the  next page button
# 43883
# Could not find the  next page button
# 44363
# Could not find the  next page button
# 46093
# Could not find the  next page button
# 49195
# Could not find the  next page button
# 53839
# ...

# %%
len(scraper.list_dics_links)
# Out:
# 3

# %%
for dic in scraper.list_dics_links:
    print(len(dic['links']))
# Out:
# 61
# 591
# 2274
# 5409
# 6641
# 5814
# 3428
# 7042
# 61
# 632
# 2273
# 5358
# 6582
# 5821
# 3388
# 7035
# 61
# 604
# 2270
# 5356
# 6592

# %%
import json

# %%
links = json.dumps(scraper.list_dics_links)

# %%
btn = self.driver.find_element_by_xpath("//span[contains(@class, 'sr-only') and text()='Next page']")
btn = btn.find_element_by_xpath('..')
btn.c

# %%
help(scraper.driver)
# Out:
# Help on WebDriver in module selenium.webdriver.chrome.webdriver object:
#
# class WebDriver(selenium.webdriver.remote.webdriver.WebDriver)
#  |  WebDriver(executable_path='chromedriver', port=0, options=None, service_args=None, desired_capabilities=None, service_log_path=None, chrome_options=None, keep_alive=True)
#  |
#  |  Controls the ChromeDriver and allows you to drive the browser.
#  |
#  |  You will need to download the ChromeDriver executable from
#  |  http://chromedriver.storage.googleapis.com/index.html
#  |
#  |  Method resolution order:
#  |      WebDriver
#  |      selenium.webdriver.remote.webdriver.WebDriver
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, executable_path='chromedriver', port=0, options=None, service_args=None, desired_capabilities=None, service_log_path=None, chrome_options=None, keep_alive=True)
#  |      Creates a new instance of the chrome driver.
#  |
# ...

# %%
scraper.driver.find_element_by_class_name("pagination__link pagination__link--next button button--text button--size-small")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-19-09f15b5b67cb> in <module>
# ----> 1 scraper.driver.find_element_by_class_name("pagination__link pagination__link--next button button--text button--size-small")
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
<span class="test-button__text">
    Test Text
</span>

# %%
scraper.driver.find_element_by_xpath("//span[contains(@class, 'test-button__text') and text()='Test Text']")

# %%
<a href="https://www.immoweb.be/en/search/house/for-sale?countries=BE&amp;page=332&amp;orderBy=relevance" 
class="pagination__link pagination__link--next button button--text button--size-small">
<span class="sr-only">
    Next page
</span> <svg width="18" height="18" viewBox="0 0 18 18" xmlns="http://www.w3.org/2000/svg" class="button__icon"><path d="M6.31434 3.3157C5.89522 3.73482 5.89522 4.41186 6.31434 4.83097L10.484 9.00068L6.31434 13.1704C5.89522 13.5895 5.89522 14.2665 6.31434 14.6857C6.73346 15.1048 7.4105 15.1048 7.82962 14.6857L12.7623 9.75294C13.1815 9.33382 13.1815 8.65679 12.7623 8.23767L7.82962 3.30495C7.42125 2.89658 6.73346 2.89658 6.31434 3.3157Z"></path></svg></a>

# %%
btn =scraper.driver.find_element_by_xpath("//span[contains(@class, 'sr-only') and text()='Next page']")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-30-6d582205026a> in <module>
# ----> 1 btn =scraper.driver.find_element_by_xpath("//span[contains(@class, 'sr-only') and text()='Next page']")
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
btn = btn.find_element_by_xpath('..')
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-31-41a6ff082eec> in <module>
# ----> 1 btn = btn.find_element_by_xpath('..')
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_xpath(self, xpath)
#     349             element = element.find_element_by_xpath('//div/td[1]')
#     350         """
# --> 351         return self.find_element(by=By.XPATH, value=xpath)
#     352
#     353     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# --> 658         return self._execute(Command.FIND_CHILD_ELEMENT,
#     659                              {"using": by, "value": value})['value']
#     660
#
# ...

# %%
btn.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-32-3277f2a8dd51> in <module>
# ----> 1 btn.click()
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\envs\becode_env\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
import json

# %%
jsonStr = json.dumps(scraper.list_dics_links)

# %%
list(scraper.set_links)
# Out:
# 86613

# %%
from time import time

# %%
jsonStr = json.dumps(list(scraper.set_links))
loc = f'./data{int(time())}.txt'
with open(loc, 'w') as outfile:
    json.dump(jsonStr, outfile)

# %%
json.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-217-6039d16a546f> in <module>
# ----> 1 json.save()
#
# AttributeError: module 'json' has no attribute 'save'

# %%
jsonStr
# Out:
# '[{"property_type": "house", "min-max_price": [0, 50000], "links": ["https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8991260?searchId=6011b04a00f66", "/en/classified/8651556", "https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/9016148?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/apartment/for-sale/enghien/7850/9116268?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/apartment/for-sale/laeken-(bru.)/1020/9125429?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8670795?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/apartment/for-sale/watermael-boitsfort/1170/9129987?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/service-flat/for-sale/brasschaat/2930/8688291?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/apartment/for-sale/oostende/8400/8929256?searchId=6011b04a00f66", "https://www.immoweb.be/en/classified/apartment/for-sale/de-h
# ...

# %%
scraper.list_dics_links
# Out:
# [{'property_type': 'house',
#   'min-max_price': (0, 50000),
#   'links': ['https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8991260?searchId=6011b04a00f66',
#    '/en/classified/8651556',
#    'https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/9016148?searchId=6011b04a00f66',
#    'https://www.immoweb.be/en/classified/apartment/for-sale/enghien/7850/9116268?searchId=6011b04a00f66',
#    'https://www.immoweb.be/en/classified/apartment/for-sale/laeken-(bru.)/1020/9125429?searchId=6011b04a00f66',
#    'https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8670795?searchId=6011b04a00f66',
#    'https://www.immoweb.be/en/classified/apartment/for-sale/watermael-boitsfort/1170/9129987?searchId=6011b04a00f66',
#    'https://www.immoweb.be/en/classified/service-flat/for-sale/brasschaat/2930/8688291?searchId=6011b04a00f66',
#    'https://www.immoweb.be/en/classified/apartment/for-sale/oostende/8400/8929256?searchId=6011b04a00f66',
# ...

# %%
html_list = scraper.driver.find_element_by_id("main-content")
items = html_list.find_elements_by_tag_name("li")
for item in items:
    print(item.text)
    break
# Out:
# Apartment
# €40,000 + €860/month
# 40000€ + 860€ per month
# 2 bdr.
# 2 bedrooms
# · 100 m²
# square meters
# 4020 Liège
# Viager occupé !! Très bel appartement en bord de Meuse
# LIFE ANNUITY

# %%
innerHTML = item.get_attribute('innerHTML')
compiled = re.compile("https://www.immoweb.be[\w]")
compiled = re.compile("https://www.immoweb.be[/w]{20}")

# %%
items = html_list.find_elements_by_tag_name("li")
for item in items:
    try:
        innerHTML = item.get_attribute('innerHTML')
        link = innerHTML.split('href="')[1].split('" ')[0]
        print(link)
    except:
        print(innerHTML)
# Out:
# https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8991260?searchId=6011aa28b98dc
# /en/classified/8651556
# https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/9016148?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/apartment/for-sale/enghien/7850/9116268?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/apartment/for-sale/laeken-(bru.)/1020/9125429?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8670795?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/apartment/for-sale/watermael-boitsfort/1170/9129987?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/service-flat/for-sale/brasschaat/2930/8688291?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/apartment/for-sale/oostende/8400/8929256?searchId=6011aa28b98dc
# https://www.immoweb.be/en/classified/apartment/for-sale/de-haan/8420/9103317?searchId=6011aa28b98dc
# ...

# %%
print(dirk)
# Out:
# None

# %%
innerHTML
# Out:
# '<article id="classified_8991260" data-fakeid="882e075a-6672-49d5-bd61-c39c44444b98" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-0e832a7f-6274-4cc1-a8f0-9eec4b92e7fc-classified_8991260" class="card--result__body"><!----> <h2 id="card-882e075a-6672-49d5-bd61-c39c44444b98-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8991260?searchId=6011aa28b98dc" aria-label="Apartment for sale, Liège (40000€ + 860€ per month)" class="card__title-link">\n                    Apartment\n                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€40,000 + €860/month</span> <span class="sr-only">\n        40000€ + 860€ per month\n    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">\n        2 bdr.\n    <
# ...

# %%
item.find_elements_by_css_selector("[href]")[0].text
# Out:
# 'Apartment'

# %%
<ul id="main-content" class="search-results__list" style="opacity: 1;"><li class="search-results__item"><article id="classified_8991260" data-fakeid="35e500ae-8b13-4fb3-995e-57bf49637b43" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-b27e657a-624b-4bb0-a71a-29c4539ab5cd-classified_8991260" class="card--result__body"><!----> <h2 id="card-35e500ae-8b13-4fb3-995e-57bf49637b43-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8991260?searchId=601182718456a" aria-label="Apartment for sale, Liège (40000€ + 860€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€40,000 + €860/month</span> <span class="sr-only">
        40000€ + 860€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        2 bdr.
    </span> <span class="sr-only">
        2 bedrooms
    </span></span> 
                        ·
                     

                        100

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                4020 Liège
            </p></div> <div class="card__description card--result__description">
            Viager occupé !! Très bel appartement en bord de Meuse
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/3292073.gif?cache=2019430905890" alt="TREVI LIEGE" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-35e500ae-8b13-4fb3-995e-57bf49637b43" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/8/9/9/1/2/6/0/8991260_1.jpg?cache=20201026202421" id="cardMediaPicture-35e500ae-8b13-4fb3-995e-57bf49637b43" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><!----> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <img src="https://static.immoweb.be/pics/peb/peb_b.png" alt="Energy class : B" title="Energy class : B" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-051b0dac-d597-47e9-bf09-f13e7d5c1fe9"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-051b0dac-d597-47e9-bf09-f13e7d5c1fe9)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><!----> <!----> <!----> <div><div id="adfocus_0" class="adfocus"><div class="adfocus__media"><div class="adfocus__media-picture" style="background-size: cover; background-image: url(&quot;https://static.immoweb.be/photos/0/8/6/5/1/5/5/6/M_8651556_1.jpg?cache=20200620204556&quot;);"></div> <!----></div> <div class="adfocus__content"><span title="This property has been promoted by our partners in your region" class="sponsorised-label">Sponsored</span> <a tabindex="0" href="/en/classified/8651556" class="adfocus__link adfocus__link-title">LIEGE | 1-2-3 bedroom apartments &amp; penthouses</a> <p class="adfocus__from">Starting from</p> <p aria-hidden="true" class="adfocus__price">€176,000<span class="sr-only">176000€</span></p> <p class="adfocus__infos"><span class="sr-only">
                            1 - 3 Bedrooms
                        </span> <span aria-hidden="true">
                            1 - 3 bdr.
                        </span> <span class="adfocus__infos-separator"></span> 
                    66 - 163
                    <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span></p> <p class="adfocus__location">4020 - Liege
            </p> <div class="adfocus__logo-container"><img src="https://static.immoweb.be/logos/1912369.gif?cache=201952090511Z" alt="Thomas &amp; Piron - Bâtiment" class="adfocus__logo"></div></div></div></div> <!----> <!----></li><li class="search-results__item"><article id="classified_9016148" data-fakeid="444787e3-cb32-4149-aabb-c054e97e4517" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-c82b15a9-df72-4b2c-a197-204ff759b69c-classified_9016148" class="card--result__body"><!----> <h2 id="card-444787e3-cb32-4149-aabb-c054e97e4517-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/9016148?searchId=601182718456a" aria-label="Apartment for sale, Liège (25000€ + 655€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€25,000 + €655/month</span> <span class="sr-only">
        25000€ + 655€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        3 bdr.
    </span> <span class="sr-only">
        3 bedrooms
    </span></span> 
                        ·
                     

                        142

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                4020 Liège
            </p></div> <div class="card__description card--result__description">
            Viager occupé -  Bel appartement 3 chambres
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/3292073.gif?cache=2019430905890" alt="TREVI LIEGE" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-444787e3-cb32-4149-aabb-c054e97e4517" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/9/0/1/6/1/4/8/9016148_1.jpg?cache=20201029194926" id="cardMediaPicture-444787e3-cb32-4149-aabb-c054e97e4517" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><!----> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <img src="https://static.immoweb.be/pics/peb/peb_c.png" alt="Energy class : C" title="Energy class : C" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-68a7f1ca-95e2-4cfe-ba1b-681069ef0662"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-68a7f1ca-95e2-4cfe-ba1b-681069ef0662)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_9116268" data-fakeid="67e04766-9ca1-4efd-9781-fc87c5f53754" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-76787c81-ee6b-4eed-9503-2fe12301336d-classified_9116268" class="card--result__body"><!----> <h2 id="card-67e04766-9ca1-4efd-9781-fc87c5f53754-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/enghien/7850/9116268?searchId=601182718456a" aria-label="Apartment for sale, Enghien (20000€ + 1350€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€20,000 + €1,350/month</span> <span class="sr-only">
        20000€ + 1350€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        3 bdr.
    </span> <span class="sr-only">
        3 bedrooms
    </span></span> 
                        ·
                     

                        214

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                7850 Enghien
            </p></div> <div class="card__description card--result__description">
            LUXURY PROPERTY
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/1533169.gif?cache=2016061503943" alt="Trevi Haute Senne" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-67e04766-9ca1-4efd-9781-fc87c5f53754" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/9/1/1/6/2/6/8/9116268_1.jpg?cache=20210113123418" id="cardMediaPicture-67e04766-9ca1-4efd-9781-fc87c5f53754" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><div class="flag-list__item flag-list__item--main"><span class="flag-list__text">
                Under option
            </span></div> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <img src="https://static.immoweb.be/pics/peb/peb_g.png" alt="Energy class : G" title="Energy class : G" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-0ace6536-a715-4a40-b371-bfe520282a91"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-0ace6536-a715-4a40-b371-bfe520282a91)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_9125429" data-fakeid="54c51c13-99a3-4f52-84ed-ed44c02a09f7" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-7aa31220-26bb-40f6-91a5-e6e56f221544-classified_9125429" class="card--result__body"><!----> <h2 id="card-54c51c13-99a3-4f52-84ed-ed44c02a09f7-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/laeken-(bru.)/1020/9125429?searchId=601182718456a" aria-label="Apartment for sale, LAEKEN (BRU.) (20000€ + 580€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€20,000 + €580/month</span> <span class="sr-only">
        20000€ + 580€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        1 bdr.
    </span> <span class="sr-only">
        1 bedroom
    </span></span> 
                        ·
                     

                        56

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                1020 LAEKEN (BRU.)
            </p></div> <div class="card__description card--result__description">
            Apartment
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/1599.gif?cache=2016061503933" alt="TREVI  GROUP" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-54c51c13-99a3-4f52-84ed-ed44c02a09f7" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/9/1/2/5/4/2/9/9125429_1.jpg?cache=20210119125428" id="cardMediaPicture-54c51c13-99a3-4f52-84ed-ed44c02a09f7" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><div class="flag-list__item flag-list__item--main"><span class="flag-list__text">
                new
            </span></div> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <!----> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-3a1de173-8001-4f2d-92bd-7893a83f17a1"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-3a1de173-8001-4f2d-92bd-7893a83f17a1)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_8670795" data-fakeid="aae365ff-c7b8-4fff-94b7-e04c3a350bdc" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-a2b2675f-a9c8-41ac-9aef-7e0da1c8df14-classified_8670795" class="card--result__body"><!----> <h2 id="card-aae365ff-c7b8-4fff-94b7-e04c3a350bdc-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8670795?searchId=601182718456a" aria-label="Apartment for sale, Liège (35000€ + 955€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">

# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-a3c9264dc0cf> in <module>
# ----> 1 for house in scraper.lst:
#       2     print(house)
#
# TypeError: 'WebElement' object is not iterable

# %%
scraper.choose_transaction_type('Buy')

# %%
btn = scraper.driver.find_element_by_xpath('//*[@id="minPrice"]')
btn.send_keys(2323)
btn.send_keys(Keys.ENTER)

# %%
<ul id="main-content" class="search-results__list" style="opacity: 1;"><li class="search-results__item"><article id="classified_8991260" data-fakeid="4f6f20ff-6271-4ad5-a77f-ec6d1303486f" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-2bf0d674-0832-4262-9391-155744637c7b-classified_8991260" class="card--result__body"><!----> <h2 id="card-4f6f20ff-6271-4ad5-a77f-ec6d1303486f-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/8991260?searchId=6011816d023c9" aria-label="Apartment for sale, Liège (40000€ + 860€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€40,000 + €860/month</span> <span class="sr-only">
        40000€ + 860€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        2 bdr.
    </span> <span class="sr-only">
        2 bedrooms
    </span></span> 
                        ·
                     

                        100

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                4020 Liège
            </p></div> <div class="card__description card--result__description">
            Viager occupé !! Très bel appartement en bord de Meuse
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/3292073.gif?cache=2019430905890" alt="TREVI LIEGE" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-4f6f20ff-6271-4ad5-a77f-ec6d1303486f" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/8/9/9/1/2/6/0/8991260_1.jpg?cache=20201026202421" id="cardMediaPicture-4f6f20ff-6271-4ad5-a77f-ec6d1303486f" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><!----> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <img src="https://static.immoweb.be/pics/peb/peb_b.png" alt="Energy class : B" title="Energy class : B" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-b9a65ade-7f58-4a7d-a727-bce356eccd0e"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-b9a65ade-7f58-4a7d-a727-bce356eccd0e)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><!----> <!----> <!----> <div><div id="adfocus_0" class="adfocus"><div class="adfocus__media"><div class="adfocus__media-picture" style="background-size: cover; background-image: url(&quot;https://static.immoweb.be/photos/0/8/6/5/1/5/5/6/M_8651556_1.jpg?cache=20200620204556&quot;);"></div> <!----></div> <div class="adfocus__content"><span title="This property has been promoted by our partners in your region" class="sponsorised-label">Sponsored</span> <a tabindex="0" href="/en/classified/8651556" class="adfocus__link adfocus__link-title">LIEGE | 1-2-3 bedroom apartments &amp; penthouses</a> <p class="adfocus__from">Starting from</p> <p aria-hidden="true" class="adfocus__price">€176,000<span class="sr-only">176000€</span></p> <p class="adfocus__infos"><span class="sr-only">
                            1 - 3 Bedrooms
                        </span> <span aria-hidden="true">
                            1 - 3 bdr.
                        </span> <span class="adfocus__infos-separator"></span> 
                    66 - 163
                    <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span></p> <p class="adfocus__location">4020 - Liege
            </p> <div class="adfocus__logo-container"><img src="https://static.immoweb.be/logos/1912369.gif?cache=201952090511Z" alt="Thomas &amp; Piron - Bâtiment" class="adfocus__logo"></div></div></div></div> <!----> <!----></li><li class="search-results__item"><article id="classified_9016148" data-fakeid="f94beaf3-282f-4850-b3f1-165d92b192c1" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-90cc8087-80db-4203-ab4e-ae9cad171df8-classified_9016148" class="card--result__body"><!----> <h2 id="card-f94beaf3-282f-4850-b3f1-165d92b192c1-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/liege/4020/9016148?searchId=6011816d023c9" aria-label="Apartment for sale, Liège (25000€ + 655€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€25,000 + €655/month</span> <span class="sr-only">
        25000€ + 655€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        3 bdr.
    </span> <span class="sr-only">
        3 bedrooms
    </span></span> 
                        ·
                     

                        142

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                4020 Liège
            </p></div> <div class="card__description card--result__description">
            Viager occupé -  Bel appartement 3 chambres
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/3292073.gif?cache=2019430905890" alt="TREVI LIEGE" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-f94beaf3-282f-4850-b3f1-165d92b192c1" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/9/0/1/6/1/4/8/9016148_1.jpg?cache=20201029194926" id="cardMediaPicture-f94beaf3-282f-4850-b3f1-165d92b192c1" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><!----> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <img src="https://static.immoweb.be/pics/peb/peb_c.png" alt="Energy class : C" title="Energy class : C" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-9555b587-7e96-4f45-af72-cfc8f8fa2e83"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-9555b587-7e96-4f45-af72-cfc8f8fa2e83)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_
class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/8/9/6/4/3/5/4/8964354_1.jpg?cache=20201001093419" id="cardMediaPicture-93a6243b-4c26-4674-b83a-4b7736cc90b5" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><div class="flag-list__item flag-list__item--main"><span class="flag-list__text">
                Under option
            </span></div> </div> <img src="https://static.immoweb.be/pics/peb/peb_g.png" alt="Energy class : G" title="Energy class : G" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-f91577b0-cec1-4ce1-8f8f-e5c002a49575"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-f91577b0-cec1-4ce1-8f8f-e5c002a49575)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_8983370" data-fakeid="2b13a8a2-5074-4313-bc64-b4ed92fced8b" class="card card--result card--large"><div id="lazy-loading-observer-wrapper-d0028a06-0cb0-4ac0-add8-4e8cba3ef1df-classified_8983370" class="card--result__body"><!----> <h2 id="card-2b13a8a2-5074-4313-bc64-b4ed92fced8b-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/evere/1140/8983370?searchId=6011816d023c9" aria-label="Apartment for sale, Evere (40000€ + 700€ per month)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€40,000 + €700/month</span> <span class="sr-only">
        40000€ + 700€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        1 bdr.
    </span> <span class="sr-only">
        1 bedroom
    </span></span> 
                        ·
                     

                        65

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                1140 Evere
            </p></div> <!----> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/1485883.gif?cache=2017150804573" alt="VIAGERIM - JF.Jacobs" class="card__logo card--result__logo card__logo--large"></div></div> <div class="card--result__media"><div id="cardMediaContainer-2b13a8a2-5074-4313-bc64-b4ed92fced8b" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/8/9/8/3/3/7/0/8983370_2.jpg?cache=20201012093737" id="cardMediaPicture-2b13a8a2-5074-4313-bc64-b4ed92fced8b" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><!----> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <!----> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-5c6cb9d6-881d-4cb0-90e7-4a4d3d6ee864"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-5c6cb9d6-881d-4cb0-90e7-4a4d3d6ee864)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_8559593" data-fakeid="14d72ebe-973e-4d84-bda6-8a51c7a6c637" class="card card--result card--large"><div id="lazy-loading-observer-wrapper-ece2bcd2-2a03-4b11-bc07-9e14ad10e74f-classified_8559593" class="card--result__body"><!----> <h2 id="card-14d72ebe-973e-4d84-bda6-8a51c7a6c637-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/frameries/7080/8559593?searchId=6011816d023c9" aria-label="Apartment for sale, Frameries (30000€)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€30,000</span> <span class="sr-only">
        30000€
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        1 bdr.
    </span> <span class="sr-only">
        1 bedroom
    </span></span> 
                        ·
                     

                        144

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                7080 Frameries
            </p></div> <!----> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/1161242.gif?cache=2016200809487" alt="Logissim" class="card__logo card--result__logo card__logo--large"></div></div> <div class="card--result__media"><div id="cardMediaContainer-14d72ebe-973e-4d84-bda6-8a51c7a6c637" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/8/5/5/9/5/9/3/8559593_1.jpg?cache=20200930161429" id="cardMediaPicture-14d72ebe-973e-4d84-bda6-8a51c7a6c637" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <!----> <img src="https://static.immoweb.be/pics/peb/peb_f.png" alt="Energy class : F" title="Energy class : F" class="card__certificate"> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-bcc75a6d-6333-46aa-a9d9-e4163cb319ee"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-bcc75a6d-6333-46aa-a9d9-e4163cb319ee)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li><li class="search-results__item"><article id="classified_9127753" data-fakeid="c00b1648-9457-4845-92c2-da4bd5399efd" class="card card--result card--large"><div id="lazy-loading-observer-wrapper-dfbd0939-600c-449d-8972-007de1c0ce11-classified_9127753" class="card--result__body"><!----> <h2 id="card-c00b1648-9457-4845-92c2-da4bd5399efd-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/ground-floor/for-sale/woluwe-st-lambert/1200/9127753?searchId=6011816d023c9" aria-label="Ground floor for sale, Woluwe-St-Lambert (25000€ + 650€ per month)" class="card__title-link">
                    Ground floor
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€25,000 + €650/month</span> <span class="sr-only">
        25000€ + 650€ per month
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        1 bdr.
    </span> <span class="sr-only">
        1 bedroom
    </span></span> 
                        ·
                     

                        60

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                1200 Woluwe-St-Lambert
            </p></div> <!----> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/1485883.gif?cache=2017150804573" alt="VIAGERIM - JF.Jacobs" class="card__logo card--result__logo card__logo--large"></div></div> <div class="card--result__media"><div id="cardMediaContainer-c00b1648-9457-4845-92c2-da4bd5399efd" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/9/1/2/7/7/5/3/9127753_2.jpg?cache=20210120101732" id="cardMediaPicture-c00b1648-9457-4845-92c2-da4bd5399efd" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><div class="flag-list__item flag-list__item--main"><span class="flag-list__text">
                new
            </span></div> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">life annuity</span></div></div> <!----> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-7d09671d-c770-4d0a-863b-b270272b0743"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-7d09671d-c770-4d0a-863b-b270272b0743)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li></ul>

# %%
from selenium.webdriver.support.ui import WebDriverWait
